# %% [markdown]
# # Data Science Capstone project

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# ...
# Solving environment: |
# ...
#   - anaconda/linux-64::ca-certificates-2019.8.28-0, anaconda/linux-64::conda-4.8.1-py37_0, anaconda/linux-64::openssl-1.1.1d-h7b6447c_2
#   - anaconda/linux-64::ca-certificates-2019.8.28-0, anaconda/linux-64::openssl-1.1.1d-h7b6447c_2, defaults/linux-64::conda-4.8.1-py37_0
#   - anaconda/linux-64::ca-certificates-2019.8.28-0, anaconda/linux-64::conda-4.8.1-py37_0, defaults/linux-64::openssl-1.1.1d-h7b6447c_2
#   - anaconda/linux-64::ca-certificates-2019.8.28-0, defaults/linux-64::conda-4.8.1-py37_0, defaults/linux-64::openssl-1.1.1d-h7b6447c_2
#   - anaconda/linux-64::conda-4.8.1-py37_0, defaults/linux-64::ca-certificates-2019.8.28-0, defaults/linux-64::openssl-1.1.1d-h7b6447c_2
#   - defaults/linux-64::ca-certificates-2019.8.28-0, defaults/linux-64::conda-4.8.1-py37_0, defaults/linux-64::openssl-1.1.1d-h7b6447c_2
#   - anaconda/linux-64::conda-4.8.1-py37_0, anaconda/linux-64::openssl-1.1.1d-h7b6447c_2, defaults/linux-64::ca-certificates-2019.8.28-0
# ...

# %%
CLIENT_ID = 'RYF0QYZLZRUS145KXN4EUBE5ZC3GSFI3EN3HPJIEF4LE45D0' # your Foursquare ID
CLIENT_SECRET = 'JRKJIRCGFUTKA3JJHDLOP3ZF4WIB5CEOTLTHXVJ5OLHM4CM4' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: RYF0QYZLZRUS145KXN4EUBE5ZC3GSFI3EN3HPJIEF4LE45D0
# CLIENT_SECRET:JRKJIRCGFUTKA3JJHDLOP3ZF4WIB5CEOTLTHXVJ5OLHM4CM4

# %%
address = 'Pegasus,Georgetown, GY'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 6.824908 -58.162066633823386

# %%
address2 = 'Marriot,Georgetown, GY'

geolocator = Nominatim(user_agent="foursquare_agent")
location2 = geolocator.geocode(address2)
latitude2 = location.latitude2
longitude2 = location.longitude2
print(latitude2, longitude2)

# %%
search_query = 'Restaurant'
radius = 5000
print(search_query + ' .... OK!')
# Out:
# Restaurant .... OK!

# %%
search_query2 = 'School'
radius = 5000
print(search_query2 + ' .... OK!')
# Out:
# School .... OK!

# %%
search_query3 = 'University'
radius = 5000
print(search_query3 + ' .... OK!')
# Out:
# University .... OK!

# %%
search_query4 = 'Hotel'
radius = 5000
print(search_query4 + ' .... OK!')
# Out:
# Hotel .... OK!

# %%
search_query5 = 'Hospital'
radius = 5000
print(search_query5 + ' .... OK!')
# Out:
# Hospital .... OK!

# %%
search_query6 = 'Police'
radius = 5000
print(search_query6 + ' .... OK!')
# Out:
# Police .... OK!

# %%
search_query7 = 'Shopping Mall'
radius = 5000
print(search_query7 + ' .... OK!')
# Out:
# Shopping Mall .... OK!

# %%
search_query8 = 'Market'
radius = 5000
print(search_query8 + ' .... OK!')
# Out:
# Market .... OK!

# %%
search_query9 = 'Night Club'
radius = 5000
print(search_query9 + ' .... OK!')
# Out:
# Night Club .... OK!

# %%
search_query10 = 'Bank'
radius = 5000
print(search_query10 + ' .... OK!')
# Out:
# Bank .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=RYF0QYZLZRUS145KXN4EUBE5ZC3GSFI3EN3HPJIEF4LE45D0&client_secret=JRKJIRCGFUTKA3JJHDLOP3ZF4WIB5CEOTLTHXVJ5OLHM4CM4&ll=6.824908,-58.162066633823386&v=20180604&query=Restaurant&radius=5000&limit=30'

# %%
url2 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query2, radius, LIMIT)
url2
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=RYF0QYZLZRUS145KXN4EUBE5ZC3GSFI3EN3HPJIEF4LE45D0&client_secret=JRKJIRCGFUTKA3JJHDLOP3ZF4WIB5CEOTLTHXVJ5OLHM4CM4&ll=6.824908,-58.162066633823386&v=20180604&query=School&radius=5000&limit=30'

# %%
url3 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query3, radius, LIMIT)
url3
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=RYF0QYZLZRUS145KXN4EUBE5ZC3GSFI3EN3HPJIEF4LE45D0&client_secret=JRKJIRCGFUTKA3JJHDLOP3ZF4WIB5CEOTLTHXVJ5OLHM4CM4&ll=6.824908,-58.162066633823386&v=20180604&query=University&radius=5000&limit=30'

# %%
url4 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query4, radius, LIMIT)
url4
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=RYF0QYZLZRUS145KXN4EUBE5ZC3GSFI3EN3HPJIEF4LE45D0&client_secret=JRKJIRCGFUTKA3JJHDLOP3ZF4WIB5CEOTLTHXVJ5OLHM4CM4&ll=6.824908,-58.162066633823386&v=20180604&query=Hotel&radius=5000&limit=30'

# %%
url5 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query5, radius, LIMIT)
url5
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=RYF0QYZLZRUS145KXN4EUBE5ZC3GSFI3EN3HPJIEF4LE45D0&client_secret=JRKJIRCGFUTKA3JJHDLOP3ZF4WIB5CEOTLTHXVJ5OLHM4CM4&ll=6.824908,-58.162066633823386&v=20180604&query=Hospital&radius=5000&limit=30'

# %%
url6 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query6, radius, LIMIT)
url6
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=RYF0QYZLZRUS145KXN4EUBE5ZC3GSFI3EN3HPJIEF4LE45D0&client_secret=JRKJIRCGFUTKA3JJHDLOP3ZF4WIB5CEOTLTHXVJ5OLHM4CM4&ll=6.824908,-58.162066633823386&v=20180604&query=Police&radius=5000&limit=30'

# %%
url7 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query7, radius, LIMIT)
url7
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=RYF0QYZLZRUS145KXN4EUBE5ZC3GSFI3EN3HPJIEF4LE45D0&client_secret=JRKJIRCGFUTKA3JJHDLOP3ZF4WIB5CEOTLTHXVJ5OLHM4CM4&ll=6.824908,-58.162066633823386&v=20180604&query=Shopping Mall&radius=5000&limit=30'

# %%
url8 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query8, radius, LIMIT)
url8
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=RYF0QYZLZRUS145KXN4EUBE5ZC3GSFI3EN3HPJIEF4LE45D0&client_secret=JRKJIRCGFUTKA3JJHDLOP3ZF4WIB5CEOTLTHXVJ5OLHM4CM4&ll=6.824908,-58.162066633823386&v=20180604&query=Market&radius=5000&limit=30'

# %%
url9 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query9, radius, LIMIT)
url9
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=RYF0QYZLZRUS145KXN4EUBE5ZC3GSFI3EN3HPJIEF4LE45D0&client_secret=JRKJIRCGFUTKA3JJHDLOP3ZF4WIB5CEOTLTHXVJ5OLHM4CM4&ll=6.824908,-58.162066633823386&v=20180604&query=Night Club&radius=5000&limit=30'

# %%
url10 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query10, radius, LIMIT)
url10
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=RYF0QYZLZRUS145KXN4EUBE5ZC3GSFI3EN3HPJIEF4LE45D0&client_secret=JRKJIRCGFUTKA3JJHDLOP3ZF4WIB5CEOTLTHXVJ5OLHM4CM4&ll=6.824908,-58.162066633823386&v=20180604&query=Bank&radius=5000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e29ab9b83525f001b9941c6'},
#  'response': {'venues': [{'id': '4fb04e08e4b0c546fb2ad7ac',
#     'name': 'The Flame Restaurant',
#     'location': {'address': 'Hotel Tower',
#      'crossStreet': 'Main Street',
#      'lat': 6.824818192101576,
#      'lng': -58.162056371562684,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 6.824818192101576,
#        'lng': -58.162056371562684}],
#      'distance': 10,
#      'cc': 'GY',
#      'city': 'Georgetown',
#      'state': 'Demerara-Mahaica Region',
#      'country': 'Guyana',
#      'formattedAddress': ['Hotel Tower (Main Street)',
#       'Georgetown',
#       'Guyana']},
#     'categories': [{'id': '4bf58dd8d48988d144941735',
#       'name': 'Caribbean Restaurant',
#       'pluralName': 'Caribbean Restaurants',
#       'shortName': 'Caribbean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#        'suffix': '.png'},
#       'primary': True}],
# ...

# %%
results2 = requests.get(url2).json()
results2
# Out:
# {'meta': {'code': 200, 'requestId': '5e29aaf10cc1fd001b3ba30c'},
#  'response': {'venues': [{'id': '51225a19e4b00b0e663050dd',
#     'name': 'Arthur Lok Jack (Graduate School of Business)',
#     'location': {'address': 'Church Street',
#      'lat': 6.81299,
#      'lng': -58.163773,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 6.81299,
#        'lng': -58.163773}],
#      'distance': 1340,
#      'cc': 'GY',
#      'city': 'Georgetown',
#      'state': 'Demerara-Mahaica Region',
#      'country': 'Guyana',
#      'formattedAddress': ['Church Street', 'Georgetown', 'Guyana']},
#     'categories': [{'id': '4bf58dd8d48988d1a8941735',
#       'name': 'General College & University',
#       'pluralName': 'General Colleges & Universities',
#       'shortName': 'Education',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579789089',
# ...

# %%
results3 = requests.get(url3).json()
results3
# Out:
# {'meta': {'code': 200, 'requestId': '5e29aafd78a484001bd146d9'},
#  'response': {'venues': [{'id': '5c123deebf7dde002cf2fe2c',
#     'name': 'Lincoln American University',
#     'location': {'address': '8A & 8B, Kingston',
#      'crossStreet': 'Water & Barrack Street',
#      'lat': 6.822666499076003,
#      'lng': -58.164878368443176,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 6.822666499076003,
#        'lng': -58.164878368443176}],
#      'distance': 398,
#      'cc': 'GY',
#      'city': 'Kingston',
#      'state': 'George Town',
#      'country': 'Guyana',
#      'formattedAddress': ['8A & 8B, Kingston (Water & Barrack Street)',
#       'Kingston',
#       'Guyana']},
#     'categories': [{'id': '4bf58dd8d48988d1b3941735',
#       'name': 'Medical School',
#       'pluralName': 'Medical Schools',
#       'shortName': 'Medical School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
# ...

# %%
results4 = requests.get(url4).json()
results4
# Out:
# {'meta': {'code': 200, 'requestId': '5e29aabbb4b684001b03eff9'},
#  'response': {'venues': [{'id': '4e432f18483b132669c7a172',
#     'name': 'Pegasus Hotel',
#     'location': {'address': 'Sea Wall Road',
#      'lat': 6.825086442936071,
#      'lng': -58.1618338151962,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 6.825086442936071,
#        'lng': -58.1618338151962}],
#      'distance': 32,
#      'cc': 'GY',
#      'city': 'Georgetown',
#      'state': 'Demerara-Mahaica Region',
#      'country': 'Guyana',
#      'formattedAddress': ['Sea Wall Road', 'Georgetown', 'Guyana']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579789096',
#     'hasPerk': False},
#    {'id': '5537938b498eeecc232c91b3',
# ...

# %%
results5 = requests.get(url5).json()
results5
# Out:
# {'meta': {'code': 200, 'requestId': '5e29ab05b1cac0001bd35d39'},
#  'response': {'venues': [{'id': '4fcec8b9e4b074e7070ede36',
#     'name': 'St. Joseph Mercy Hospital',
#     'location': {'address': '130-132 Parade St',
#      'crossStreet': 'Between Young And Barrack St',
#      'lat': 6.822321991205129,
#      'lng': -58.1607663528037,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 6.822321991205129,
#        'lng': -58.1607663528037}],
#      'distance': 321,
#      'cc': 'GY',
#      'city': 'Kingston',
#      'state': 'Georgetown',
#      'country': 'Guyana',
#      'formattedAddress': ['130-132 Parade St (Between Young And Barrack St)',
#       'Kingston',
#       'Guyana']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
# ...

# %%
results6 = requests.get(url6).json()
results6
# Out:
# {'meta': {'code': 200, 'requestId': '5e29b24f0de0d9001b0bd755'},
#  'response': {'venues': [{'id': '512cf3b5e4b04520d8e8ec9d',
#     'name': 'Police HQ',
#     'location': {'address': 'Eve Leary',
#      'crossStreet': 'Camp St.',
#      'lat': 6.804611,
#      'lng': -58.15483099999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 6.804611,
#        'lng': -58.15483099999999}],
#      'distance': 2396,
#      'cc': 'GY',
#      'city': 'Georgetown',
#      'state': 'Demerara-Mahaica Region',
#      'country': 'Guyana',
#      'formattedAddress': ['Eve Leary (Camp St.)', 'Georgetown', 'Guyana']},
#     'categories': [{'id': '4bf58dd8d48988d12e941735',
#       'name': 'Police Station',
#       'pluralName': 'Police Stations',
#       'shortName': 'Police Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_policestation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579790936',
# ...

# %%
results7 = requests.get(url7).json()
results7
# Out:
# {'meta': {'code': 200, 'requestId': '5e29aaae95feaf001b2b1982'},
#  'response': {'venues': [{'id': '4e593bc918388cd5cba0bf10',
#     'name': 'City Mall',
#     'location': {'address': 'Regent Street',
#      'crossStreet': 'Camp Street',
#      'lat': 6.81024281042918,
#      'lng': -58.16058972871827,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 6.81024281042918,
#        'lng': -58.16058972871827}],
#      'distance': 1640,
#      'cc': 'GY',
#      'city': 'Georgetown',
#      'state': 'Demerara-Mahaica Region',
#      'country': 'Guyana',
#      'formattedAddress': ['Regent Street (Camp Street)',
#       'Georgetown',
#       'Guyana']},
#     'categories': [{'id': '4bf58dd8d48988d1fd941735',
#       'name': 'Shopping Mall',
#       'pluralName': 'Shopping Malls',
#       'shortName': 'Mall',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579789108',
# ...

# %%
results8 = requests.get(url8).json()
results8
# Out:
# {'meta': {'code': 200, 'requestId': '5e29aa8d40a7ea001c79c376'},
#  'response': {'venues': [{'id': '4e6f86a98998fd5c56b0d51e',
#     'name': 'Stabroek Market',
#     'location': {'address': 'Stabroek',
#      'lat': 6.8090176695493065,
#      'lng': -58.16289600389163,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 6.8090176695493065,
#        'lng': -58.16289600389163}],
#      'distance': 1771,
#      'cc': 'GY',
#      'city': 'Georgetown',
#      'state': 'Demerara-Mahaica Region',
#      'country': 'Guyana',
#      'formattedAddress': ['Stabroek', 'Georgetown', 'Guyana']},
#     'categories': [{'id': '4bf58dd8d48988d1fd941735',
#       'name': 'Shopping Mall',
#       'pluralName': 'Shopping Malls',
#       'shortName': 'Mall',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579789111',
#     'hasPerk': False},
#    {'id': '5290a518498e2213ab656739',
# ...

# %%
results9 = requests.get(url9).json()
results9
# Out:
# {'meta': {'code': 200, 'requestId': '5e29aadaa2e538001be41d72'},
#  'response': {'venues': [{'id': '4e50397f18383eb2af2d7d63',
#     'name': 'Night Cap',
#     'location': {'address': '8 Pere Street, Kitty',
#      'lat': 6.824579944189548,
#      'lng': -58.13784321885648,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 6.824579944189548,
#        'lng': -58.13784321885648}],
#      'distance': 2677,
#      'cc': 'GY',
#      'city': 'Georgetown',
#      'state': 'Demerara-Mahaica Region',
#      'country': 'Guyana',
#      'formattedAddress': ['8 Pere Street, Kitty', 'Georgetown', 'Guyana']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579789117',
#     'hasPerk': False},
#    {'id': '4f9da00de4b0d2a3aa3d34e0',
# ...

# %%
results10 = requests.get(url10).json()
results10
# Out:
# {'meta': {'code': 200, 'requestId': '5e29b192aba297001c26116f'},
#  'response': {'venues': [{'id': '4e31832c483b1bbfc5ae4a55',
#     'name': 'GBTI bank',
#     'location': {'lat': 6.824984255686967,
#      'lng': -58.161433602014995,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 6.824984255686967,
#        'lng': -58.161433602014995}],
#      'distance': 70,
#      'cc': 'GY',
#      'city': 'Georgetown',
#      'state': 'Demerara-Mahaica Region',
#      'country': 'Guyana',
#      'formattedAddress': ['Georgetown', 'Guyana']},
#     'categories': [],
#     'referralId': 'v-1579790965',
#     'hasPerk': False},
#    {'id': '572c6dea498e8539a17edbb6',
#     'name': 'GBTI Bank',
#     'location': {'lat': 6.824187,
#      'lng': -58.161376,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 6.824187,
#        'lng': -58.161376}],
#      'distance': 110,
#      'cc': 'GY',
#      'country': 'Guyana',
#      'formattedAddress': ['Guyana']},
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id                         name  \
# 0  4fb04e08e4b0c546fb2ad7ac         The Flame Restaurant
# 1  4de3ca091f6e3190cd2f77b2           Maharaj Restaurant
# 2  4dc986d48130552d881d913c           Upscale Restaurant
# 3  4dd53e23e4cd1c4babcc7706          German's Restaurant
# 4  4fc2b5f6e4b05b85039cd119  Buddy's Mei Tung Restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d144941735', 'name': 'C...  v-1579789240    False
# 1  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...  v-1579789240    False
# 2  [{'id': '4bf58dd8d48988d144941735', 'name': 'C...  v-1579789240    False
# 3                                                 []  v-1579789240    False
# 4  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1579789240    False
#
#       location.address location.crossStreet  location.lat  location.lng  \
# 0          Hotel Tower          Main Street      6.824818    -58.162056
# ...

# %%
# assign relevant part of JSON to venues
venues2 = results2['response']['venues']

# tranform venues into a dataframe
dataframe2 = json_normalize(venues2)
dataframe2.head()
# Out:
#                          id                                           name  \
# 0  51225a19e4b00b0e663050dd  Arthur Lok Jack (Graduate School of Business)
# 1  4ed405e4c2eee2de8f240b42                         St. Rose's High school
# 2  547dab4b498e8c3372821e74                        St Agnes Primary School
# 3  50fd7433e4b0a8cca980ca8c                          School of the Nations
# 4  524435a511d2e83abe2caec3                       Airy Hall nursery school
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1a8941735', 'name': 'G...  v-1579789089    False
# 1                                                 []  v-1579789089    False
# 2  [{'id': '4bf58dd8d48988d1a2941735', 'name': 'C...  v-1579789089    False
# 3  [{'id': '4bf58dd8d48988d1a8941735', 'name': 'G...  v-1579789089    False
# 4  [{'id': '4bf58dd8d48988d1ad941735', 'name': 'T...  v-1579789089    False
#
# ...

# %%
# assign relevant part of JSON to venues
venues3 = results3['response']['venues']

# tranform venues into a dataframe
dataframe3 = json_normalize(venues3)
dataframe3.head()
# Out:
#                          id                                           name  \
# 0  5c123deebf7dde002cf2fe2c                    Lincoln American University
# 1  5c10d5290a08ab002c43d513             Lincoln American University LAUMED
# 2  5148ecade4b09817b54cc396  University of the Southern Caribbean (Guyana)
# 3  51323902e4b054cc6c21c773                            Nation's University
# 4  516c3e73498ee0be26ca9380                    University of Guyana Campus
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1b3941735', 'name': 'M...  v-1579789092    False
# 1  [{'id': '4bf58dd8d48988d1ae941735', 'name': 'U...  v-1579789092    False
# 2  [{'id': '4bf58dd8d48988d199941735', 'name': 'C...  v-1579789092    False
# 3  [{'id': '4bf58dd8d48988d1ae941735', 'name': 'U...  v-1579789092    False
# 4  [{'id': '4bf58dd8d48988d1a8941735', 'name': 'G...  v-1579789092    False
#
# ...

# %%
# assign relevant part of JSON to venues
venues4 = results4['response']['venues']

# tranform venues into a dataframe
dataframe4 = json_normalize(venues4)
dataframe4.head()
# Out:
#                          id                              name  \
# 0  4e432f18483b132669c7a172                     Pegasus Hotel
# 1  5537938b498eeecc232c91b3  Guyana Marriott Hotel Georgetown
# 2  4f8d86b3e4b08101161aee9b        Poolside@The_Pegasus_Hotel
# 3  52177e2a8bbda98c8e18057c                 Kings Plaza Hotel
# 4  52255c2611d2fedde05c119a                      Halito Hotel
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1579789096    False
# 1  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1579789096    False
# 2  [{'id': '4bf58dd8d48988d15e941735', 'name': 'P...  v-1579789096    False
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1579789096    False
# 4                                                 []  v-1579789096    False
#
#                       location.address  location.lat  location.lng  \
# ...

# %%
# assign relevant part of JSON to venues
venues5 = results5['response']['venues']

# tranform venues into a dataframe
dataframe5 = json_normalize(venues5)
dataframe5.head()
# Out:
#                          id                                    name  \
# 0  4fcec8b9e4b074e7070ede36               St. Joseph Mercy Hospital
# 1  51d35c2e498ea5b1f2f57e44                      Woodlands Hospital
# 2  4e7417c77d8b917602766f35  Georgetown Public Hospital Corporation
# 3  53eba9f5498ee4a59d51a982           Balwant Singh's Hospital Inc.
# 4  532dd9da498effc44e1e4a74            Dr. Balwant Singh's Hospital
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d196941735', 'name': 'H...  v-1579789100    False
# 1  [{'id': '4bf58dd8d48988d196941735', 'name': 'H...  v-1579789100    False
# 2                                                 []  v-1579789100    False
# 3  [{'id': '4bf58dd8d48988d196941735', 'name': 'H...  v-1579789100    False
# 4  [{'id': '4bf58dd8d48988d196941735', 'name': 'H...  v-1579789100    False
#
#     location.address          location.crossStreet  location.lat  \
# ...

# %%
# assign relevant part of JSON to venues
venues6 = results6['response']['venues']

# tranform venues into a dataframe
dataframe6 = json_normalize(venues6)
dataframe6.head()
# Out:
#                          id       name  \
# 0  512cf3b5e4b04520d8e8ec9d  Police HQ
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d12e941735', 'name': 'P...  v-1579790936    False
#
#   location.address location.crossStreet  location.lat  location.lng  \
# 0        Eve Leary             Camp St.      6.804611    -58.154831
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 6.804611, 'lng': ...               2396
#
#   location.cc location.city           location.state location.country  \
# 0          GY    Georgetown  Demerara-Mahaica Region           Guyana
#
#                     location.formattedAddress
# 0  [Eve Leary (Camp St.), Georgetown, Guyana]

# %%
# assign relevant part of JSON to venues
venues7 = results7['response']['venues']

# tranform venues into a dataframe
dataframe7 = json_normalize(venues7)
dataframe7.head()
# Out:
#                          id                             name  \
# 0  4e593bc918388cd5cba0bf10                        City Mall
# 1  504e46a2e4b0eb5d1fab65d4  Scotiabank ATM @ Courtyard Mall
# 2  535fc8ba498ee0f203dbbfa8                MultiComplex Mall
# 3  5230c637498e85d35e28a236            Empire Shopping Plaza
# 4  535fc9b011d2da3050886ae2                  Foot Steps Mall
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...  v-1579789108    False
# 1  [{'id': '4bf58dd8d48988d10a951735', 'name': 'B...  v-1579789108    False
# 2  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...  v-1579789108    False
# 3  [{'id': '4bf58dd8d48988d116951735', 'name': 'A...  v-1579789108    False
# 4  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...  v-1579789108    False
#
#         location.address       location.crossStreet  location.lat  \
# 0          Regent Street                Camp Street      6.810243
# ...

# %%
# assign relevant part of JSON to venues
venues8 = results8['response']['venues']

# tranform venues into a dataframe
dataframe8 = json_normalize(venues8)
dataframe8.head()
# Out:
#                          id                      name  \
# 0  4e6f86a98998fd5c56b0d51e           Stabroek Market
# 1  5290a518498e2213ab656739             Bourda Market
# 2  520c0b3b498ebf872dd94c01  Marketing & Distribution
# 3  509439eae4b03c3d2e4f1b2e           Kojac Marketing
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...  v-1579789111    False
# 1  [{'id': '50be8ee891d4fa8dcc7199a7', 'name': 'M...  v-1579789111    False
# 2  [{'id': '4bf58dd8d48988d1ff941735', 'name': 'M...  v-1579789111    False
# 3  [{'id': '4bf58dd8d48988d1ff941735', 'name': 'M...  v-1579789111    False
#
#   location.address  location.lat  location.lng  \
# 0         Stabroek      6.809018    -58.162896
# 1    Regent Street      6.820468    -58.120566
# 2              NaN      6.793740    -58.167432
# 3              NaN      6.814289    -58.162062
#
# ...

# %%
# assign relevant part of JSON to venues
venues9 = results9['response']['venues']

# tranform venues into a dataframe
dataframe9 = json_normalize(venues9)
dataframe9.head()
# Out:
#                          id                     name  \
# 0  4e50397f18383eb2af2d7d63                Night Cap
# 1  4f9da00de4b0d2a3aa3d34e0     Everest Cricket Club
# 2  4ebed3af61af06192ad14adc      The Georgetown Club
# 3  4dcf30f545ddbe15f89d66a1  Club Edge (Tower Hotel)
# 4  521a79b8498e7008318594b9   Malteenoes Sports Club
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1579789117    False
# 1  [{'id': '4f4528bc4b90abdf24c9de85', 'name': 'A...  v-1579789117    False
# 2  [{'id': '52e81612bcbc57f1066b7a2d', 'name': 'S...  v-1579789117    False
# 3                                                 []  v-1579789117    False
# 4  [{'id': '4f4528bc4b90abdf24c9de85', 'name': 'A...  v-1579789117    False
#
#        location.address  location.lat  location.lng  \
# 0  8 Pere Street, Kitty      6.824580    -58.137843
# 1                   NaN      6.821370    -58.156402
# ...

# %%
# assign relevant part of JSON to venues
venues10 = results10['response']['venues']

# tranform venues into a dataframe
dataframe10 = json_normalize(venues10)
dataframe10.head()
# Out:
#                          id                                name  \
# 0  4e31832c483b1bbfc5ae4a55                           GBTI bank
# 1  572c6dea498e8539a17edbb6                           GBTI Bank
# 2  541308cf498e95912ce55802  Guyana Bank for Trade and Industry
# 3  4e6fb64bb3ad44d0b72200bf                 Bank of Nova Scotia
# 4  5134c8b9e4b0b7da6e2731c4      InterAmerican Development Bank
#
#                                           categories    referralId  hasPerk  \
# 0                                                 []  v-1579790965    False
# 1  [{'id': '4bf58dd8d48988d10a951735', 'name': 'B...  v-1579790965    False
# 2  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...  v-1579790965    False
# 3  [{'id': '4bf58dd8d48988d10a951735', 'name': 'B...  v-1579790965    False
# 4  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...  v-1579790965    False
#
#    location.lat  location.lng  \
# 0      6.824984    -58.161434
# 1      6.824187    -58.161376
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                       name          categories                    address  \
# 0                Night Cap                Café       8 Pere Street, Kitty
# 1     Everest Cricket Club  Athletics & Sports                        NaN
# 2      The Georgetown Club        Squash Court               208 Camp St.
# 3  Club Edge (Tower Hotel)                None                Main Street
# 4   Malteenoes Sports Club  Athletics & Sports                Thomaslands
# 5  Georgetown Cricket Club      Cricket Ground     Shiv Chanderpaul Drive
# 6           El club latino                 Bar  57 hadfeild & lime street
# 7       Movietown DVD Club                None            43 Croal Street
# 8              Club Monaco           Nightclub                        NaN
# 9  Club bed with dj pillow     Other Nightlife                       Home
#
#         lat        lng                                     labeledLatLngs  \
# 0  6.824580 -58.137843  [{'label': 'display', 'lat': 6.824579944189548...
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns2 = ['name', 'categories'] + [col for col in dataframe2.columns if col.startswith('location.')] + ['id']
dataframe_filtered2 = dataframe2.loc[:, filtered_columns2]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list2 = row['categories']
    except:
        categories_list2 = row['venue.categories']
        
    if len(categories_list2) == 0:
        return None
    else:
        return categories_list2[0]['name']

# filter the category for each row
dataframe_filtered2['categories'] = dataframe_filtered2.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered2.columns = [column.split('.')[-1] for column in dataframe_filtered2.columns]

dataframe_filtered2
# Out:
#                                             name  \
# 0  Arthur Lok Jack (Graduate School of Business)
# 1                         St. Rose's High school
# 2                        St Agnes Primary School
# 3                          School of the Nations
# 4                       Airy Hall nursery school
# 5      American International School of Medicine
# 6                                Business School
# 7                East Ruimveldt Secondary School
# 8                              New Guyana School
#
#                      categories  \
# 0  General College & University
# 1                          None
# 2             Community College
# 3  General College & University
# 4                  Trade School
# 5                Medical School
# 6                          None
# 7             College Classroom
# 8                Student Center
#
#                                           address       lat        lng  \
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns3 = ['name', 'categories'] + [col for col in dataframe3.columns if col.startswith('location.')] + ['id']
dataframe_filtered3 = dataframe3.loc[:, filtered_columns3]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list3 = row['categories']
    except:
        categories_list3 = row['venue.categories']
        
    if len(categories_list3) == 0:
        return None
    else:
        return categories_list3[0]['name']

# filter the category for each row
dataframe_filtered3['categories'] = dataframe_filtered3.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered3.columns = [column.split('.')[-1] for column in dataframe_filtered3.columns]

dataframe_filtered3
# Out:
#                                             name  \
# 0                    Lincoln American University
# 1             Lincoln American University LAUMED
# 2  University of the Southern Caribbean (Guyana)
# 3                            Nation's University
# 4                    University of Guyana Campus
# 5                  GreenHeart Medical University
# 6                           University of Guyana
# 7                     Texila American University
# 8          GreenHeart Medical University(Pre-Md)
# 9                 Georgetown American University
#
#                      categories  \
# 0                Medical School
# 1                    University
# 2         College Arts Building
# 3                    University
# 4  General College & University
# 5                Medical School
# 6                    University
# 7                Medical School
# 8                Medical School
# 9                Medical School
#
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns4 = ['name', 'categories'] + [col for col in dataframe4.columns if col.startswith('location.')] + ['id']
dataframe_filtered4 = dataframe4.loc[:, filtered_columns4]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list4 = row['categories']
    except:
        categories_list4 = row['venue.categories']
        
    if len(categories_list4) == 0:
        return None
    else:
        return categories_list4[0]['name']

# filter the category for each row
dataframe_filtered4['categories'] = dataframe_filtered4.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered4.columns = [column.split('.')[-1] for column in dataframe_filtered4.columns]

dataframe_filtered4
# Out:
#                                 name  \
# 0                      Pegasus Hotel
# 1   Guyana Marriott Hotel Georgetown
# 2         Poolside@The_Pegasus_Hotel
# 3                  Kings Plaza Hotel
# 4                       Halito Hotel
# 5                    Tropicana Hotel
# 6        King’s Hotel And Residences
# 7                     Ariantze Hotel
# 8            Club Edge (Tower Hotel)
# 9                    Tower Hotel Gym
# 10                Serenity Inn Hotel
# 11                      Luxury Hotel
# 12              Regency Suites/Hotel
# 13                Hotel Atlantic Inn
# 14       Regency International Hotel
# 15                        Opus Hotel
# 16       Sleepin International Hotel
# 17             Millenium Manor Hotel
# 18                  The Palace Hotel
# 19                 Ocean Spray Hotel
# 20          Glow Internatiinal Hotel
# 21                       Tower Hotel
# 22        Status International Hotel
# 23                      Durban Hotel
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns5 = ['name', 'categories'] + [col for col in dataframe5.columns if col.startswith('location.')] + ['id']
dataframe_filtered5 = dataframe5.loc[:, filtered_columns5]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

# filter the category for each row
dataframe_filtered5['categories'] = dataframe_filtered5.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered5.columns = [column.split('.')[-1] for column in dataframe_filtered5.columns]

dataframe_filtered5
# Out:
#                                      name categories            address  \
# 0               St. Joseph Mercy Hospital   Hospital  130-132 Parade St
# 1                      Woodlands Hospital   Hospital                NaN
# 2  Georgetown Public Hospital Corporation       None  New Market Street
# 3           Balwant Singh's Hospital Inc.   Hospital    314 East Street
# 4            Dr. Balwant Singh's Hospital   Hospital                NaN
# 5                         Island Hospital   Hospital         Georgetown
#
#                     crossStreet       lat        lng  \
# 0  Between Young And Barrack St  6.822322 -58.160766
# 1                           NaN  6.818076 -58.161656
# 2                           NaN  6.816301 -58.156652
# 3            South Cummingsburg  6.814056 -58.156518
# 4                           NaN  6.813876 -58.156305
# 5                           NaN  6.804611 -58.154831
#
#                                       labeledLatLngs  distance  cc  \
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns6 = ['name', 'categories'] + [col for col in dataframe6.columns if col.startswith('location.')] + ['id']
dataframe_filtered6 = dataframe6.loc[:, filtered_columns6]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list6 = row['categories']
    except:
        categories_list6 = row['venue.categories']
        
    if len(categories_list6) == 0:
        return None
    else:
        return categories_list6[0]['name']

# filter the category for each row
dataframe_filtered6['categories'] = dataframe_filtered6.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered6.columns = [column.split('.')[-1] for column in dataframe_filtered6.columns]

dataframe_filtered6
# Out:
#         name      categories    address crossStreet       lat        lng  \
# 0  Police HQ  Police Station  Eve Leary    Camp St.  6.804611 -58.154831
#
#                                       labeledLatLngs  distance  cc  \
# 0  [{'label': 'display', 'lat': 6.804611, 'lng': ...      2396  GY
#
#          city                    state country  \
# 0  Georgetown  Demerara-Mahaica Region  Guyana
#
#                              formattedAddress                        id
# 0  [Eve Leary (Camp St.), Georgetown, Guyana]  512cf3b5e4b04520d8e8ec9d

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns7 = ['name', 'categories'] + [col for col in dataframe7.columns if col.startswith('location.')] + ['id']
dataframe_filtered7 = dataframe7.loc[:, filtered_columns7]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list7 = row['categories']
    except:
        categories_list7 = row['venue.categories']
        
    if len(categories_list7) == 0:
        return None
    else:
        return categories_list7[0]['name']

# filter the category for each row
dataframe_filtered7['categories'] = dataframe_filtered7.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered7.columns = [column.split('.')[-1] for column in dataframe_filtered7.columns]

dataframe_filtered7
# Out:
#                                        name              categories  \
# 0                                 City Mall           Shopping Mall
# 1           Scotiabank ATM @ Courtyard Mall                    Bank
# 2                         MultiComplex Mall           Shopping Mall
# 3                     Empire Shopping Plaza            Antique Shop
# 4                           Foot Steps Mall           Shopping Mall
# 5                     Empire Shopping Plaza  Furniture / Home Store
# 6                     Pulse Online Shopping          Shipping Store
# 7                Pizza Hut at Giftland Mall             Pizza Place
# 8                Pizza Hut at Giftland Mall             Pizza Place
# 9   Royal Castle Giftland Mall (Food Court)     Fried Chicken Joint
# 10                  Publik at Giftland Mall          Sandwich Place
# 11                              Dairy Queen          Ice Cream Shop
# 12         Java Coffee Bar at Giftland Mall             Coffee Shop
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns8 = ['name', 'categories'] + [col for col in dataframe8.columns if col.startswith('location.')] + ['id']
dataframe_filtered8 = dataframe8.loc[:, filtered_columns8]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list8 = row['categories']
    except:
        categories_list8 = row['venue.categories']
        
    if len(categories_list8) == 0:
        return None
    else:
        return categories_list8[0]['name']

# filter the category for each row
dataframe_filtered8['categories'] = dataframe_filtered8.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered8.columns = [column.split('.')[-1] for column in dataframe_filtered8.columns]

dataframe_filtered8
# Out:
#                        name          categories        address       lat  \
# 0           Stabroek Market       Shopping Mall       Stabroek  6.809018
# 1             Bourda Market              Market  Regent Street  6.820468
# 2  Marketing & Distribution  Miscellaneous Shop            NaN  6.793740
# 3           Kojac Marketing  Miscellaneous Shop            NaN  6.814289
#
#          lng                                     labeledLatLngs  distance  cc  \
# 0 -58.162896  [{'label': 'display', 'lat': 6.809017669549306...      1771  GY
# 1 -58.120566  [{'label': 'display', 'lat': 6.82046802324649,...      4613  GY
# 2 -58.167432  [{'label': 'display', 'lat': 6.79374, 'lng': -...      3519  GY
# 3 -58.162062  [{'label': 'display', 'lat': 6.814289106127517...      1182  GY
#
#          city                    state country  \
# 0  Georgetown  Demerara-Mahaica Region  Guyana
# 1  Georgetown  Demerara-Mahaica Region  Guyana
# 2         NaN                      NaN  Guyana
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns9 = ['name', 'categories'] + [col for col in dataframe9.columns if col.startswith('location.')] + ['id']
dataframe_filtered9 = dataframe9.loc[:, filtered_columns9]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list9 = row['categories']
    except:
        categories_list9 = row['venue.categories']
        
    if len(categories_list9) == 0:
        return None
    else:
        return categories_list9[0]['name']

# filter the category for each row
dataframe_filtered9['categories'] = dataframe_filtered9.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered9.columns = [column.split('.')[-1] for column in dataframe_filtered9.columns]

dataframe_filtered9
# Out:
#                       name          categories                    address  \
# 0                Night Cap                Café       8 Pere Street, Kitty
# 1     Everest Cricket Club  Athletics & Sports                        NaN
# 2      The Georgetown Club        Squash Court               208 Camp St.
# 3  Club Edge (Tower Hotel)                None                Main Street
# 4   Malteenoes Sports Club  Athletics & Sports                Thomaslands
# 5  Georgetown Cricket Club      Cricket Ground     Shiv Chanderpaul Drive
# 6           El club latino                 Bar  57 hadfeild & lime street
# 7       Movietown DVD Club                None            43 Croal Street
# 8              Club Monaco           Nightclub                        NaN
# 9  Club bed with dj pillow     Other Nightlife                       Home
#
#         lat        lng                                     labeledLatLngs  \
# 0  6.824580 -58.137843  [{'label': 'display', 'lat': 6.824579944189548...
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns10 = ['name', 'categories'] + [col for col in dataframe10.columns if col.startswith('location.')] + ['id']
dataframe_filtered10 = dataframe10.loc[:, filtered_columns10]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list10 = row['categories']
    except:
        categories_list10 = row['venue.categories']
        
    if len(categories_list10) == 0:
        return None
    else:
        return categories_list10[0]['name']

# filter the category for each row
dataframe_filtered10['categories'] = dataframe_filtered10.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered10.columns = [column.split('.')[-1] for column in dataframe_filtered10.columns]

dataframe_filtered10
# Out:
#                                      name        categories       lat  \
# 0                               GBTI bank              None  6.824984
# 1                               GBTI Bank              Bank  6.824187
# 2      Guyana Bank for Trade and Industry            Office  6.824326
# 3                     Bank of Nova Scotia              Bank  6.819122
# 4          InterAmerican Development Bank            Office  6.821792
# 5               Republic Bank Head Office              Bank  6.818184
# 6                          Bank of Guyana  Capitol Building  6.813405
# 7                          Bank of Guyana  Capitol Building  6.814791
# 8   Blood Bank Lamaha Street - Georgetown              None  6.817561
# 9                          Bank of Baroda              Bank  6.811427
# 10     Guyana Bank for Trade and Industry              Bank  6.810999
# 11                          Citizens Bank              Bank  6.809644
# ...

# %%
dataframe_filtered.name
# Out:
# 0                  Night Cap
# 1       Everest Cricket Club
# 2        The Georgetown Club
# 3    Club Edge (Tower Hotel)
# 4     Malteenoes Sports Club
# 5    Georgetown Cricket Club
# 6             El club latino
# 7         Movietown DVD Club
# 8                Club Monaco
# 9    Club bed with dj pillow
# Name: name, dtype: object

# %%
dataframe_filtered2.name
# Out:
# 0    Arthur Lok Jack (Graduate School of Business)
# 1                           St. Rose's High school
# 2                          St Agnes Primary School
# 3                            School of the Nations
# 4                         Airy Hall nursery school
# 5        American International School of Medicine
# 6                                  Business School
# 7                  East Ruimveldt Secondary School
# 8                                New Guyana School
# Name: name, dtype: object

# %%
dataframe_filtered3.name
# Out:
# 0                      Lincoln American University
# 1               Lincoln American University LAUMED
# 2    University of the Southern Caribbean (Guyana)
# 3                              Nation's University
# 4                      University of Guyana Campus
# 5                    GreenHeart Medical University
# 6                             University of Guyana
# 7                       Texila American University
# 8            GreenHeart Medical University(Pre-Md)
# 9                   Georgetown American University
# Name: name, dtype: object

# %%
dataframe_filtered4.name
# Out:
# 0                        Pegasus Hotel
# 1     Guyana Marriott Hotel Georgetown
# 2           Poolside@The_Pegasus_Hotel
# 3                    Kings Plaza Hotel
# 4                         Halito Hotel
# 5                      Tropicana Hotel
# 6          King’s Hotel And Residences
# 7                       Ariantze Hotel
# 8              Club Edge (Tower Hotel)
# 9                      Tower Hotel Gym
# 10                  Serenity Inn Hotel
# 11                        Luxury Hotel
# 12                Regency Suites/Hotel
# 13                  Hotel Atlantic Inn
# 14         Regency International Hotel
# 15                          Opus Hotel
# 16         Sleepin International Hotel
# 17               Millenium Manor Hotel
# 18                    The Palace Hotel
# 19                   Ocean Spray Hotel
# 20            Glow Internatiinal Hotel
# 21                         Tower Hotel
# 22          Status International Hotel
# 23                        Durban Hotel
# ...

# %%
dataframe_filtered5.name
# Out:
# 0                 St. Joseph Mercy Hospital
# 1                        Woodlands Hospital
# 2    Georgetown Public Hospital Corporation
# 3             Balwant Singh's Hospital Inc.
# 4              Dr. Balwant Singh's Hospital
# 5                           Island Hospital
# Name: name, dtype: object

# %%
dataframe_filtered6.name
# Out:
# 0    Police HQ
# Name: name, dtype: object

# %%
dataframe_filtered7.name
# Out:
# 0                                   City Mall
# 1             Scotiabank ATM @ Courtyard Mall
# 2                           MultiComplex Mall
# 3                       Empire Shopping Plaza
# 4                             Foot Steps Mall
# 5                       Empire Shopping Plaza
# 6                       Pulse Online Shopping
# 7                  Pizza Hut at Giftland Mall
# 8                  Pizza Hut at Giftland Mall
# 9     Royal Castle Giftland Mall (Food Court)
# 10                    Publik at Giftland Mall
# 11                                Dairy Queen
# 12           Java Coffee Bar at Giftland Mall
# 13                              Giftland Mall
# Name: name, dtype: object

# %%
dataframe_filtered8.name
# Out:
# 0             Stabroek Market
# 1               Bourda Market
# 2    Marketing & Distribution
# 3             Kojac Marketing
# Name: name, dtype: object

# %%
dataframe_filtered9.name
# Out:
# 0                  Night Cap
# 1       Everest Cricket Club
# 2        The Georgetown Club
# 3    Club Edge (Tower Hotel)
# 4     Malteenoes Sports Club
# 5    Georgetown Cricket Club
# 6             El club latino
# 7         Movietown DVD Club
# 8                Club Monaco
# 9    Club bed with dj pillow
# Name: name, dtype: object

# %%
dataframe_filtered10.name
# Out:
# 0                                 GBTI bank
# 1                                 GBTI Bank
# 2        Guyana Bank for Trade and Industry
# 3                       Bank of Nova Scotia
# 4            InterAmerican Development Bank
# 5                 Republic Bank Head Office
# 6                            Bank of Guyana
# 7                            Bank of Guyana
# 8     Blood Bank Lamaha Street - Georgetown
# 9                            Bank of Baroda
# 10       Guyana Bank for Trade and Industry
# 11                            Citizens Bank
# 12                  Republic Bank (Guy) Ltd
# 13                Republic Bank Camp Street
# 14                        Demerara Bank Ltd
# 15              Citizens Bank (Thirst Park)
# 16                              Meadow Bank
# 17                               Scotiabank
# 18                            Banks DIH Ltd
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Pegasus Hotel

# add a red circle marker to represent the Pegasus Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Pegasus',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)


# display map
#venues_map
# add the school as orange circle markers
for lat, lng, label in zip(dataframe_filtered2.lat, dataframe_filtered2.lng, dataframe_filtered2.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='orange',
        popup=label,
        fill = True,
        fill_color='orange',
        fill_opacity=0.6
    ).add_to(venues_map)


# add the university as green circle markers
for lat, lng, label in zip(dataframe_filtered3.lat, dataframe_filtered3.lng, dataframe_filtered3.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='green',
        popup=label,
        fill = True,
        fill_color='green',
        fill_opacity=0.6
    ).add_to(venues_map)
    
# add the hotel as yellow circle markers
for lat, lng, label in zip(dataframe_filtered4.lat, dataframe_filtered4.lng, dataframe_filtered4.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='yellow',
        popup=label,
        fill = True,
        fill_color='yellow',
        fill_opacity=0.6
    ).add_to(venues_map) 
# display map
    
# add the hospital as purple circle markers
for lat, lng, label in zip(dataframe_filtered5.lat, dataframe_filtered5.lng, dataframe_filtered5.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='purple',
        popup=label,
        fill = True,
        fill_color='purple',
        fill_opacity=0.6
    ).add_to(venues_map)

# add the police as brown circle markers
for lat, lng, label in zip(dataframe_filtered6.lat, dataframe_filtered6.lng, dataframe_filtered6.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='brown',
        popup=label,
        fill = True,
        fill_color='brown',
        fill_opacity=0.6
    ).add_to(venues_map)
    
# add the shopping malls as khaki circle markers
for lat, lng, label in zip(dataframe_filtered7.lat, dataframe_filtered7.lng, dataframe_filtered7.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='khaki',
        popup=label,
        fill = True,
        fill_color='khaki',
        fill_opacity=0.6
    ).add_to(venues_map)

# add the markets as grey circle markers
for lat, lng, label in zip(dataframe_filtered8.lat, dataframe_filtered8.lng, dataframe_filtered8.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='grey',
        popup=label,
        fill = True,
        fill_color='grey',
        fill_opacity=0.6
    ).add_to(venues_map)

# add the night clubs as black circle markers
for lat, lng, label in zip(dataframe_filtered9.lat, dataframe_filtered9.lng, dataframe_filtered9.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='black',
        popup=label,
        fill = True,
        fill_color='black',
        fill_opacity=0.6
    ).add_to(venues_map)

# add the bannks as pink circle markers
for lat, lng, label in zip(dataframe_filtered10.lat, dataframe_filtered10.lng, dataframe_filtered10.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='pink',
        popup=label,
        fill = True,
        fill_color='pink',
        fill_opacity=0.6
    ).add_to(venues_map)
    
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
